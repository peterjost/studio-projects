# %% [markdown]
# # National anthems - a comparison

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Loading in the dataset

# %%
df = pd.read_csv("/Users/peterjost/Downloads/studio-projects/code/NHL_underpayed_players/dollar_points.csv")
df = df.drop('Unnamed: 11', 1)
df = df.drop('Unnamed: 12', 1)
df = df.drop('Unnamed: 13', 1)
df = df.drop('Unnamed: 14', 1)
df.head(10)
# Out:
#   country       name firstname position team  games  goals  assists  points  \
# 0     CAN    McDavid    Connor        C  EDM     82     30       70     100
# 1     SWE  Arvidsson    Viktor    LW/RW  NSH     80     31       30      61
# 2     RUS    Panarin    Artemi     LW/C  CHI     82     31       43      74
# 3     DEU  Draisaitl      Leon        C  EDM     82     29       48      77
# 4     USA     Sheary     Conor       LW  PIT     61     23       30      53
# 5     CAN     Gagner       Sam     C/RW  CBJ     81     18       32      50
# 6     CZE   Pastrnak     David    RW/LW  BOS     75     34       36      70
# 7     USA   Matthews    Auston        C  TOR     82     40       29      69
# 8     DNK     Ehlers   Nikolaj       LW  WPG     82     25       39      64
# 9     FIN      Laine    Patrik       RW  WPG     73     36       28      64
#
#           salary  dollar_point
# 0  CA$925'000.00   CA$ 9250.00
# 1  CA$640'000.00  CA$ 10355.20
# 2  CA$925'000.00  CA$ 10979.73
# 3  CA$925'000.00  CA$ 12012.99
# 4  CA$667'500.00  CA$ 12594.34
# 5  CA$650'000.00  CA$ 13000.00
# 6  CA$925'000.00  CA$ 13214.29
# 7  CA$925'000.00  CA$ 13405.80
# 8  CA$925'000.00  CA$ 13971.36
# 9  CA$925'000.00  CA$ 14453.13

# %%
df.dtypes
# Out:
# country         object
# name            object
# firstname       object
# position        object
# team            object
# games            int64
# goals            int64
# assists          int64
# points           int64
# salary          object
# dollar_point    object
# dtype: object

# %%
df.head(10).plot(kind='bar')

# %%
df.sort_values(by="points", ascending=False).head(10).plot(x='name', y='points', kind='bar', color='darkgreen')

# %%
df.tail(10)
# Out:
#     country       name firstname position team  games  goals  assists  points  \
# 864     USA     Greene      Matt        D  L.A     26      1        1       2
# 865     USA     Condra      Erik       RW  T.B     13      0        0       0
# 866     USA   Callahan      Ryan       RW  T.B     18      2        2       4
# 867     CAN    Gelinas      Eric        D  COL     27      0        1       1
# 868     USA      Fayne      Mark        D  EDM      4      0        2       2
# 869     CZE   Michalek     Milan    LW/RW  TOR      5      1        1       2
# 870     CZE    Sobotka  Vladimir     LW/C  STL      1      1        0       1
# 871     CZE   Michalek    Zbynek        D  ARI      3      0        0       0
# 872     CAN    Despres     Simon        D  ANA      1      0        0       0
# 873     CAN  MacArthur    Clarke       LW  OTT      4      0        0       0
#
#               salary     dollar_point
# 864  CA$2'500'000.00   CA$ 1250000.00
# 865  CA$1'250'000.00  CA$1'250'000.00
# 866  CA$6'500'000.00   CA$ 1450000.00
# 867  CA$1'650'000.00   CA$ 1575000.00
# 868  CA$3'500'000.00   CA$ 1812500.00
# 869  CA$4'000'000.00   CA$ 2000000.00
# 870  CA$2'725'000.00   CA$ 2725000.00
# 871  CA$3'200'000.00  CA$3'200'000.00
# 872  CA$2'600'000.00  CA$3'700'000.00
# 873  CA$4'500'000.00  CA$4'650'000.00

# %%
df.sort_values(by="points", ascending=False).tail(10)
# Out:
#     country       name firstname position team  games  goals  assists  points  \
# 761     USA    Lashoff     Brian        D  DET      5      0        0       0
# 763     USA  McCormick       Max  RW/LW/C  OTT      7      0        0       0
# 774     CAN   Johnston      Ryan        D  MTL      7      0        0       0
# 764     USA     Nelson     Casey        D  BUF     11      0        0       0
# 765     CAN     Harpur       Ben        D  OTT      6      0        0       0
# 766     CAN    Lernout     Brett        D  MTL      2      0        0       0
# 768     CAN   Bertuzzi     Tyler       LW  DET      7      0        0       0
# 772     CAN    Carrier      Alex        D  NSH      2      0        0       0
# 773     CAN       Paul      Nick     LW/C  OTT      1      0        0       0
# 873     CAN  MacArthur    Clarke       LW  OTT      4      0        0       0
#
#               salary     dollar_point
# 761    CA$650'000.00    CA$650'000.00
# 763    CA$650'000.00    CA$650'000.00
# 774    CA$692'500.00    CA$680'000.00
# 764    CA$650'000.00    CA$650'000.00
# 765    CA$655'000.00    CA$653'333.00
# 766    CA$660'000.00    CA$653'333.00
# 768    CA$667'500.00    CA$661'667.00
# 772    CA$640'000.00    CA$668'333.00
# 773    CA$692'500.00    CA$670'000.00
# 873  CA$4'500'000.00  CA$4'650'000.00

# %%
df_new.sort_values(by='words', ascending=False).plot(y='words', kind='bar', color='darkblue', title='The many words of the Marseillaise')

# %%
df_new.plot(y='year', style='o', title='Many anthems were introduced around 1990')

# %% [markdown]
# Importing the wordcloud file
