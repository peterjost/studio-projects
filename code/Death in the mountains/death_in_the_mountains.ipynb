# %% [markdown]
# # Death in the mountains

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/Users/peterjost/Downloads/studio-projects/code/Death in the mountains/bfu_berg_tote.csv")
df.head()
# Out:
#    Jahr  Wandern  Bergsteigen  Klettern  Canyoning
# 0  2006       47           32         7          2
# 1  2007       51           41         5          0
# 2  2008       46           21         3          3
# 3  2009       51           23         6          0
# 4  2010       59           20         6          1

# %%
df.dtypes
# Out:
# Jahr           int64
# Wandern        int64
# Bergsteigen    int64
# Klettern       int64
# Canyoning      int64
# dtype: object

# %%
ax = df[['Wandern', 'Bergsteigen', 'Klettern', 'Canyoning']].plot(kind='bar', title ="Tote in den Bergen", figsize=(10, 5), legend=True, fontsize=12)

# %%
ax = df[['Wandern', 'Bergsteigen', 'Klettern', 'Canyoning']].plot(title ="Tote in den Bergen", figsize=(10, 5), legend=True, fontsize=12)

# %%
df2 = pd.read_csv("/Users/peterjost/Downloads/studio-projects/code/Death in the mountains/bfu_berg_herkunft.csv")
df2.head()
# Out:
#    Alter  Wandern  Bergsteigen  Klettern  Canyoning  Total
# 0    0–9      2.0          0.0       1.0        0.0    3.0
# 1  10–19     22.0          6.0       2.0        1.0   31.0
# 2  20–29     34.0         65.0      11.0        4.0  114.0
# 3  30–39     47.0         53.0       5.0        4.0  109.0
# 4  40–49     52.0         62.0       8.0        2.0  124.0

# %%
df.dtypes
# Out:
# Jahr           int64
# Wandern        int64
# Bergsteigen    int64
# Klettern       int64
# Canyoning      int64
# dtype: object

# %%
ax = df2[['Wandern', 'Bergsteigen', 'Klettern', 'Canyoning']].plot(kind='bar', title ="Tote in den Bergen", figsize=(10, 5), legend=True, fontsize=12)
